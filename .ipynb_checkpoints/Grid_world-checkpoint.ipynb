# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Hi" data-toc-modified-id="Hi-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Hi</a></span></li></ul></div>

# %%
import sys
import os

# Set ROOT_DIR to the folder containing 'core'
# In Colab/Local, this ensures imports like 'from core.Agent...' work
ROOT_DIR = os.path.abspath(os.getcwd())
if ROOT_DIR not in sys.path:
    sys.path.append(ROOT_DIR)

from core.Agent.mdp_model import FiniteMDP
from core.Agent.agent import Agent

print(f"ROOT_DIR: {ROOT_DIR}")
# Out:
# ROOT_DIR: c:\Users\gurra\OneDrive\Desktop\1Acads\sem-6\DA6400-RL\EE23B085_da6400_rl_master_repo

# %% [markdown]
# ## Hi

# %%
# Out:
# Hi
